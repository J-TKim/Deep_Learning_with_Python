# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# 코드 8-1 다른 온도 값을 사용하여 확률 분포의 가중치 바꾸기
import numpy as np

# 오리지날은 전체 합이 1인 1D넘파이 배열 temperature는 출력 분포의 엔트로피 양을 결정
def reweight_distribution(original_distribution, temperature = 0.5): 
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    
    # 원본 분포의 가중치를 변경하며 반환 이 분포의 합은 1이 아닐 수 있으므로 새로운 분포의 합으로 나눔
    return distribution / np.sum(distribution)

# %%
# 코드 8-2 원본 텍스트 파일을 내려받아 파싱하기
import keras
import numpy as np

path = keras.utils.get_file("nietzsche.txt",
                           origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt")
text = open(path).read().lower()
print("말뭉치 크기 :", len(text))
# Out:
# 말뭉치 크기 : 600893

# %%
# 코드 8-3 글자 시퀀스 벡터화하기
maxlen = 60 # 60개의 글자로 된 시퀀스를 추출합니다
step = 3 # 세 글자씩 건너뛰면서 새로운 시퀀스를 샘플링합니다

sentences = [] # 추출할 시퀀스를 담을 리스트

next_chars = [] # 타깃(시퀀스 다음 글지)을 담을 시퀀스

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print("시퀀스 개수 :", len(sentences))

chars = sorted(list(set(text))) # 말뭉치에서 고유한 글자를 담은 리스트
print("고유한 글자 :", len(chars))
char_indices = dict((char, chars.index(char)) for char in chars) # chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리

print("벡터화...")

# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다
x = np.zeros((len(sentences), maxlen, len(chars)), dtype = np.bool)
y = np.zeros((len(sentences), len(chars)), dtype = np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수 : 200278
# 고유한 글자 : 57
# 벡터화...

# %%
# 코드 8-4 다음 글자를 예측하기 위한 단일 LSTM 모델
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation="softmax"))

# %%
# 코드 8-5 모델 컴파일 설정하기
optimizer = keras.optimizers.RMSprop(lr = 0.01)
model.compile(loss = "categorical_crossentropy",
             optimizer = optimizer)

# %%
# 코드 8-6 모델의 예측이 주어졌을 때 새로운 글자를 샘플링하는 함수
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# 코드 8-7 텍스트 생성 루프
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

for epoch in range(1, 60): # 60 에포크 동안 모델을 훈련합니다
    print("에포크 :", epoch, "\n\n")
    model.fit(x, y, batch_size=128, epochs = 1) # 데이터에사 한 번만 학습해서 모델을 훈련합니다
    
    seed_text = text[start_index: start_index + maxlen] # 무작위로 시드 텍스트를 선택합니다
    print('--시드 텍스트: "' + seed_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]: # 여러가지 샘플링 온도를 시도합니다
        print("------ 온도 :", temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)
        
        for i in range(400): # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
            
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            
            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
            sys.stdout.flush()

        print()
# Out:
# 에포크 : 1
#
#
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.9624
# --시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도 : 0.2
# the slowly ascending ranks and classes, in which,
# through for the such a such a such a such a such a still to the superfice of the such a such and the such any such a such a such any such a such to the such a such a more and in the such a such a perion, and the such a pertain and the such a self and the such a such a most of the such a suct to the such a such and the such a such a perhaps of the such a such a such a pertain the such a such and possible to
# ------ 온도 : 0.5
# the slowly ascending ranks and classes, in which,
# through for the soul and such a the soul and allorican of the sume to of the will as the superation, the farule as it is the still of grature of the later the stronger, the make of the such a posiation, the such a still such and in the most continess, to the some the soul to the world of the well contain to the take however of the farm to the world to the spection, and precessent to the such an allors of th
# ------ 온도 : 1.0
# the slowly ascending ranks and classes, in which,
# through for now, alsulty", he anwaphy
# but any
# sbatove thim of hind
# bleict as
# last soulm!--of the ligeness of is its grovictiness to---have
# newlect is hatily ermonces,
# wors, all everythil to have philosophy and to will its littes fan kitirely be fins noschcse)
# vireuated in formther unowl the most law to notech, that teaneppatic nownedge involible otave,, becompered as so owk to qure, the reasionions, catical
# ------ 온도 : 1.2
# the slowly ascending ranks and classes, in which,
# through foillmoring
# lake knowlengrneraxces, cirnostiofe' such sfarally alfearticing
# come,
# reding--and imposicle have egesious, te ain kxitation of suphicow. lenceis" of single, bsuboving
# the pidengs but the,--powies? which is healtor
# not nother "ethilw, im in the but the
# ofwirdntally!
# icine"s, last
# matance. for yet whreve sulds a to haven the cingon, with the
# selling-- tilkelaten a podoaked from the
# gruard.
# 에포크 : 2
#
#
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.6185
# --시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도 : 0.2
# the slowly ascending ranks and classes, in which,
# through form the morality and began and the personal to the self the philosophers of the stranger of the stranger to the stranger to the stranger to the string to the states to the sense and interetion of the world and intermans of the postimed to the stranger of the same to the stranger of the man and soul, and the same to man to and to and intermans of the same to the states of the conducted and to the st
# ------ 온도 : 0.5
# the slowly ascending ranks and classes, in which,
# through formeld to the instinct and intermitationly in stranger nothing and store of its and respectations, it would to the strictic power to the stranger with religion of the still of the extrandly and of such a conscientific to the
# eternality, become it is to ye spirit of the strangermand in the same and man, estimings and formed for be intermoral to religious lear form the self in such a knew the great m
# ------ 온도 : 1.0
# the slowly ascending ranks and classes, in which,
# through forg totationity his generate them emnth even what fastical faith to is here in line they ancotfor-nations--an
# acts, which seive of good, sphatnation of this i slums of all can the
# hattory
# and despiceated?)--is their
# predection of hellious other, philosophers of sunvire potions which in byen and toand us only life only
# the rerew, of meder, refoged called in starimerses, as an terucle alt be daminati
# ------ 온도 : 1.2
# the slowly ascending ranks and classes, in which,
# through fowled i se! from erotion intilety or was disugrestations, all untwal vidugeratted pocured, where
# is veins to,
# -distingure by any
# ievent can on be instinicistaxitu, bitroeblioted. powerdozt that a say-(also rored to biots hipdessingur found himbounses, of paty that is from
# one knowl gashy make order deyous verboudtooved grewlattgeriticaurs). but (feminds; wher yeded and assed, euted to the
# rugro"g,
# 에포크 : 3
#
#
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.5289
# --시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도 : 0.2
# the slowly ascending ranks and classes, in which,
# through for the same and the subjection of the conductions of the same the same the soul, and the conditions of the constined to the spirits of the superions of the same and the supersting the problem of the subjection of the displays of the spirit of the spirit of the same and something of the constined to the spirit of the provest of the scienterations of the conditions of the problem of the spirits of th
# ------ 온도 : 0.5
# the slowly ascending ranks and classes, in which,
# through for a christianity of the do think the spirits and evil propers of consideration of endeed altiuse will be propostiness, as the grade and practice of his preputting with the same and the world have a so say, "even the opigionally and is and means of the out of deniauty, and
# hard upon the propers of the prove, as a deepest and nature us of the strong of moral friends,
# the was a rank of the spirit of
# ------ 온도 : 1.0
# the slowly ascending ranks and classes, in which,
# through for "raneing its disposinc, he easily how further, that the means and phende if it obbrquentmation light,
#
# everyomes whatever soul a conditions of him
# of fillling appatablibititicate they hand have into histus, lotions?
# "but it is
# mood. the dumace masications vistuch
# because
# them
# as lostly and foller,
# is yece parasilef form, and slouess). chuluction
# for phenoticistind
# wimel off fellow
# and
# are will
# a
# ------ 온도 : 1.2
# the slowly ascending ranks and classes, in which,
# through forlowness spirits of dcovemedy as if .digh, and
# ipryshisa
# been
# mask free lightd tagatim geord" of the sasked
# andiussads--when mey c"old
# and destre:
# restruction
# affact of britable, a,
# which entroble
# off
# kind of the problem
# of
# all first. fordernations of
# a scayciullous with owas must
# hutay comnles
# and genum,
# bleetness""
# and calleg, hvvew still- and mith. fowlisoper dumn mewnosisls, innot of sam, it i
# 에포크 : 4
#
#
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.4810
# --시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도 : 0.2
# the slowly ascending ranks and classes, in which,
# through for the strange and the sentiment and concerning the world and the world and into the strength and the condition that it is in the consequently the conducions and the same discopler of the man and the strange there are into the sentiment in the consequently and the states there is and so the sentiment of the consequently and problenction of the sentiment of the sentiment and the senses of the sentim
# ------ 온도 : 0.5
# the slowly ascending ranks and classes, in which,
# through for the into the far and a takes there are take and superiously and the religious will the sentiment and are even in the does inceived and more such a strange of the religion and our religious wort in consequently the disparality of the condition of man and os an the man in precess in the contrary think who make
# your state and conducing and religion and he love there is does there are "the senses of
# ------ 온도 : 1.0
# the slowly ascending ranks and classes, in which,
# through formers the insignize overse? enclivisi fole
# conceal: wite haragerance and bucch) fundard.
#
# 11lue of leadnts and some form of
# his how
# consists apport! into vervesticul and or aifals that symperation
# on a huver men of the worlds.
#
# 1leying for the rain, shorness of the ideas not himself by bad, this ischance and incase and ?lers, because his arists at
# are
# science for
# rumman
# away does theretels of the
# ------ 온도 : 1.2
# the slowly ascending ranks and classes, in which,
# through fother, level reduction,s
# and a prearing are! indeed u on manxivility by
# may-far educ of
# prophering ,ho hoted lend the leap of.
#
# ild importhed and gowe commrmoranty moralition saymacate--then one dispisionation of a experience, and into do least, is alwayiry
# de
# ries, he wail advoratible pfind to we sere
# lavour," of germann hu the insupaids ofcings it is
# are folloesing expeevinud and myneys 'ganing-g
# 에포크 : 5
#
#
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.4501
# --시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도 : 0.2
# the slowly ascending ranks and classes, in which,
# through for the more as a soul and another and profound and more the soul and the compare of the most for the sense of the same the seriel of the more the deviling and interest and destroy of the same and and most and conceals of the desired and the sense of the hatter the more the more and the compare of the same thing the seriel to the more all the subject of the sense of the subject and the man who is a
# ------ 온도 : 0.5
# the slowly ascending ranks and classes, in which,
# through for soul, and have a many this faith to the sense of general reason to be will to himself and soul of the
# comes that the senses and man, and man and dangerous,
# which seeming to to be influence as instinct of his intellocable of effect and more that the conduct as the profound as his own in fact, a stronger of the resolution of the strength and such and which it is the same thing were a religious and
# ------ 온도 : 1.0
# the slowly ascending ranks and classes, in which,
# through for itfainess with a highorly conductge, true and valuappess, viewle, in a deepent, in thet science, and fain, proor being as a certailly asconner foregos in it;
# but a demortary, thus "distruse,
# bad
# wonderning, or perceiveds, they notwecons wrong resten ogike
# to may
# be fearhadie. as it wa cangjorif olswardming of mitwabsen as pertoy as this look of finatory is rome which is a really deviling, and su
# ------ 온도 : 1.2
# the slowly ascending ranks and classes, in which,
# through for times betyours and has
# so agran
# develonm of the firstly a child handste see forance and give of what may, with long
# popular were the tedaly flueve---ciest,
# happiness, an incasal parcimands! his eaw.r, ma benevolous
# admoded and empa. simples,
# and creater linable, handged
# his course,
# knowledge. the foell it, we
# wes
# would omcreation as terming faith in order that mirilg moal renigious into a need t
# 에포크 : 6
#
#
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.4272
# --시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도 : 0.2
# the slowly ascending ranks and classes, in which,
# through for the strength the world and the soul is a superficial of the most the strange, the father the more in the experienced the subtle to be the consequently and something in the consequently and the problem of the more the strange, and the man and the consequently in the consequently the free spirit of the strictly and the strictly the strange, the proved and delight of the strange, the world and the
# ------ 온도 : 0.5
# the slowly ascending ranks and classes, in which,
# through for the fear, and and in the belief and all its experience of the barace of the man with the light the interprehendrated the contempt the sympathy of the hold longer the greatest with the spirit and
# conscience, as the assument and our appearance, and has the part of the any delight of the has to be profoundly believed, and its which present the consequently and with a perceiace may be corders of eve
# ------ 온도 : 1.0
# the slowly ascending ranks and classes, in which,
# through for where courses, and with
# the worldbor's has not more slave and delumes--fonget; with restive," for the been discisett
# in
# ; put be noty, asy
# sensuted.
# dule of stupities and "disfisests at more  negring as other youth hitherto our repiginsed. this poxises may not of religion of religions as to though ard ored, something old viationsters and the more egoina, "nchuric must be more acterful free philo
# ------ 온도 : 1.2
# the slowly ascending ranks and classes, in which,
# through for omesel, not the fwhen pitil the guloubned," as unclopa
# now calmeirable, doubt and seculage have; a comparts entired referent taken that eurome, that is,lowe; not that for sufflection. the pride one, never hale from
# the most obnen, as in advance in gooddongcisles? hard percoman hardpits. bad what it is evolfer and value un, i : necessitys
# more without hymbesour animalve raloly that.--espece and v
# 에포크 : 7
#
#
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.4099
# --시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도 : 0.2
# the slowly ascending ranks and classes, in which,
# through for the present to the spiritual interrogusn of the present to the consequently of the serious and the present the senses of the senses of the present to the present to the christian or a senses of the contemption of the serious of the spirit of the serious and of the spirit of the senses of the serious and present the senses of the former and all the present to the heart of the present the present
# ------ 온도 : 0.5
# the slowly ascending ranks and classes, in which,
# through for the sin should be thinking of his conclusion of such the deed the considered the minst and little in fore, should distingure in the promise hand in the considered and great prematic obe and of the form of
# the self-morality men and present the notion of the matter of the does in conscious or had a great men of a continual place and opinion of the self-the earth in the spiritual of the spiritly, a
# ------ 온도 : 1.0
# the slowly ascending ranks and classes, in which,
# through for years", who every
# men the repassion of this -hundrance."
# unistanding cortay
# i things in eur am obilit of cudes" itself--victor or course-aquivat now type some hictil do usily the pherecian distithed
# an evidence and exemse with the sour taken to manifoll that they were period,
# even and to what ieresify, purities or is sivoun of values, ikesped to the linely fryed every times of virtue is hourd,ue
# ------ 온도 : 1.2
# the slowly ascending ranks and classes, in which,
# through fortunation of perceinedo yhiughes having, for life of humanty the art ratonek of quiding. the perhapeaposic lobidito omjorsal misocty find all the orbiloties all will be
# dustivay of times--
# well of thinks deeped, a states and proportien figurioy. threq(yes in )yound up that he justed or the conconnesic -faith icus able thet, and genersifial, ancient in its power to manifeiliening,k" , "man stopes a
# 에포크 : 8
#
#
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.3961
# --시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도 : 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the stomer of the sentiment of the servication of the sentiment of the contempt the stomer the sentiment of the stomer, the serve of the constituted and in the stomer the servication of the philosophers and woman of the serve in the constitute who has been attain the state to the sentiments of the sentiments of the sentiments of the sentiment of the sentiments of the sentiments of t
# ------ 온도 : 0.5
# the slowly ascending ranks and classes, in which,
# through forthtivelres in the servilent, and as a down our and in the values and man and bled to here and and a victions and when the same to be called the one was to the dogmatic will seems to the most presence and in the most formords and desion from the historical can secult to be seeming one called to he who learnealy conscious of experience of the states and in the goder and to
# be love of the stomet to
# ------ 온도 : 1.0
# the slowly ascending ranks and classes, in which,
# through for much, in whom the pronly longble emotions,
# what he seems to whon
# honour, to means
# and createned be to excellers in itrivicil. when the german age fair bad oreovic philosophy characterised. at once, would awsitawing man, is dispute to in, states
# mep
# and away a apprinity or proble of hersekeots flying, let quit taste is right because igveryesed much of madicated to
# virtue of how divernal gir. the
# ------ 온도 : 1.2
# the slowly ascending ranks and classes, in which,
# through fourt, grat times o. what
# usecy of
# a
# distrity. through really, there is ceerated mens ascones; and sopt in tyoun and wijws gler--pheno natues, to vernching d jooud erh absolvite
# defens
# and it, and
# uneno be on mere wides which schezerations in mutwion those-frublite, that profting for, that it is, are to
# muty willied could per methoh afoverxernes--inintions
# and if-work ownjoriet phedment, of meriable
# 에포크 : 9
#
#
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.3831
# --시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도 : 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the strength and the same the world and the strength and souls to the same the strength to the same the subject and so the stands to the same the same the strength and the such a soul the strengther and actiness and the saint and the man and the present and pain, and the strength and present and passions and the man and the contempt to the believe of the self-mears of the strength and t
# ------ 온도 : 0.5
# the slowly ascending ranks and classes, in which,
# through for the sense of a something man of the one another another, and a power and presents, as the existence of the deviluaring books, to say, and so such its presumptions of the most truth, and to the contemptible of one another and the will them the believe of life, the way to the soul, in the fact to be distinguise and in the religions, and in the same and as the same former learners and worth which c
# ------ 온도 : 1.0
# the slowly ascending ranks and classes, in which,
# through for these "whole condition and thought, them, without the sense of
# imply--for a
# sand it has the closion, this too, adviesses to exaged, ale--arh its except becauswawn in people unforn it at any
# invelly intellemive to favourable most transformers it we distrmadines voded himself to the skeptific and to womans this daridy of anorvect.
#
# 1an mes.                         triders religion
# in a mind to se
# ------ 온도 : 1.2
# the slowly ascending ranks and classes, in which,
# through for man
# orinoral,
# "goesticive trewd more
# how sadisus oy "disour at which
# the opicion thereby testruad than toxe which four, sachording,ffol, in takan arth, duarts
# in persompamentarity)--we saupepial
# cliolable queskd also you appossible compreheniated, lersoularr. ever sucribato
# be older, to perhaps be lfond, ckpoge, oei i itunawing, under a
# ruming magrificable, womanges."
# even all, civile, toavest,
#
# 에포크 : 10
#
#
# 1484/1565 [===========================>..] - ETA: 0s - loss: 1.3729
